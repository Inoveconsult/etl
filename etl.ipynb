# %%
from src.utils import (consolidar_indicadores, classificar_e_ordenar_desempate, exportar_excel)

# %%
# destino = "C:/Projetos/ETL/Dados/SM/Esf/Resultado"
# destino = "C:/Projetos/ETL/Dados/PRT/Esf/Resultado"
# destino = "C:/Projetos/ETL/Dados/Coroata/Esf/Resultado"
destino = "C:/Projetos/ETL/Dados/Caxias/Esf/Resultados"
nota = "Conforme Nota Técnica nº 06/2025-DEAPS/SAPS/MS"
rodape=["Fonte: SISAPS- Sistema de Informação para Atenção Primária",
            "Desenvolvido por: i9 Consultoria", "Página &P de &N"]

# %%
from src.df_c1 import gerar_df_mais_acesso
nome_arquivo = "/resultado_c1.xlsx"
df_mais_acesso = gerar_df_mais_acesso()

exportar_excel(
    df_mais_acesso,
    caminho=destino + nome_arquivo,
    titulo=["C1 - Mais Acesso à Atenção Primária à Saúde",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C1"    
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c1.xlsx

# %%
from src.df_c2 import gerar_df_criancas
nome_arquivo = "/resultado_c2.xlsx"
df_crianca = gerar_df_criancas()

exportar_excel(
    df_crianca,
    caminho=destino + nome_arquivo,
    titulo=["C2 - Desenvolvimento Infanti",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C2"    
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c2.xlsx

# %%
from src.df_c3 import gerar_df_gestante_puerpera

df_gestante_puerpera = gerar_df_gestante_puerpera()

nome_arquivo = "/resultado_c3.xlsx"

exportar_excel(
    df_gestante_puerpera,
    caminho=destino + nome_arquivo,
    titulo=["C3 - Cuidado na Gestação e Puerpério",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C3"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c3.xlsx

# %%
from src.df_c4 import gerar_df_diabeticos

df_diabetes = gerar_df_diabeticos()

nome_arquivo = "/resultado_c4.xlsx"
exportar_excel(
    df_diabetes,
    caminho=destino + nome_arquivo,
    titulo=["C4 - Cuidado da pessoa com Diabetes",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C4"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c4.xlsx

# %%
from src.df_c5 import gerar_df_hipertensos
df_hipertensos = gerar_df_hipertensos()

nome_arquivo = "/resultado_c5.xlsx"

exportar_excel(
    df_hipertensos,
    caminho=destino + nome_arquivo,
    titulo=["C5 - Cuidado da pessoa com Hipertensão",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C5"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c5.xlsx

# %%
from src.df_c6 import gerar_df_idosos

df_idosos = gerar_df_idosos()

nome_arquivo = "/resultado_c6.xlsx"
exportar_excel(
    df_idosos,
    caminho=destino + nome_arquivo,
    titulo=["C6 - Cuidado integral da Pessoa Idosa",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C6"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c6.xlsx

# %%
from src.df_c7 import gerar_df_saude_mulher

df_saude_mulher = gerar_df_saude_mulher()

nome_arquivo="/resultado_c7.xlsx"

exportar_excel(
    df_saude_mulher,
    caminho=destino + nome_arquivo,
    titulo=["C7 - Cuidado da mulher na prevenção do câncer",
            nota],
    rodape=rodape,
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA C7"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_c7.xlsx

# %%
dfs = [df_mais_acesso, df_crianca, df_gestante_puerpera, df_diabetes, df_hipertensos, df_idosos, df_saude_mulher]
notas = ["NOTA C1", "NOTA C2", "NOTA C3", "NOTA C4", "NOTA C5", "NOTA C6", "NOTA C7"]
df_final = consolidar_indicadores(dfs=dfs, notas=notas)
df_final['NOTA FINAL'] = df_final[notas].sum(axis=1)
df_classificado = classificar_e_ordenar_desempate(df_final)
nome_arquivo = "/resultado_final_esf.xlsx"
exportar_excel(
    df=df_classificado,
    caminho=destino + nome_arquivo,
    titulo=["RESULTADO FINAL COMPONENTE QUALIDADE eSF 3º Quadrimestre/2025",
            nota],
    rodape=rodape,
    coluna_classificacao="CLASSIFICACAO",
    coluna_nota_final="NOTA FINAL"    
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Esf/Resultados/resultado_final_esf.xlsx
