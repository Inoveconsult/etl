# %%
from src.utils import exportar_excel, consolidar_indicadores, classificar_e_ordenar_desempate

# destino = "C:/Projetos/ETL/Dados/PRT/Emulti/Resultado"
# destino = "C:/Projetos/ETL/Dados/Coroata/Emulti/Resultado"
# destino = "C:/Projetos/ETL/Dados/SM/Emulti/Resultado"
# destino = "C:/Projetos/ETL/Dados/LP/Emulti/Resultado"
destino = "C:/Projetos/ETL/Dados/Caxias/Emulti/Resultado"

nota = "Conforme Nota Técnica nº 06/2025-DEAPS/SAPS/MS"

rodape=["Fonte: SISAPS- Sistema de Informação para Atenção Primária",
        "Desenvolvido por: i9 Consultoria",
        "Página &P de &N"]

# %%
from src.df_m1 import gerar_df_m1

nome_arquivo = "/resultado_m1.xlsx"

df_m1 = gerar_df_m1()

exportar_excel(
    df_m1,
    caminho=destino + nome_arquivo,
    titulo=["M1 - Média de atendimentos por pessoa pela e-Multi",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA M1"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Emulti/Resultado/resultado_m1.xlsx

# %%
from src.df_m2 import gerar_df_m2

nome_arquivo = "/resultado_m2.xlsx"

df_m2 = gerar_df_m2()

exportar_excel(
    df_m2,
    caminho=destino + nome_arquivo,
    titulo=["M2 - Ações interprofissionais realizadas pela e-Multi",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA M2"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Emulti/Resultado/resultado_m2.xlsx

# %%
nome_arquivo = "/resultado_final.xlsx"
dfs = [df_m1, df_m2]
notas = ["NOTA M1", "NOTA M2"]
desempate = ["NOTA M1"]
df_final = consolidar_indicadores(dfs=dfs, notas=notas)
df_final['NOTA FINAL'] = df_final[notas].sum(axis=1)
df_classificado = classificar_e_ordenar_desempate(df_final,desempate=desempate)
caminho = destino + nome_arquivo
exportar_excel(
    df=df_classificado,
    caminho=caminho,
    titulo=["RESULTADO FINAL COMPONENTE QUALIDADE e-MULTI 3º Quadrimestre/2025",
            nota],
    rodape=rodape,
    coluna_classificacao="CLASSIFICACAO",
    coluna_nota_final="NOTA FINAL"    
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Emulti/Resultado/resultado_final.xlsx
