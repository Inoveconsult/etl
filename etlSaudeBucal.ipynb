# %%
from src.utils import exportar_excel, consolidar_indicadores, classificar_e_ordenar_desempate

# destino = "C:/Projetos/ETL/Dados/PRT/Odonto/Resultado"
# destino = "C:/Projetos/ETL/Dados/Coroata/Odonto/Resultado"
# destino = "C:/Projetos/ETL/Dados/SM/Odonto/Resultado"
destino = "C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado"
# destino = "C:/Projetos/ETL/Dados/LP/Odonto/Resultado"

nota = "Conforme Nota Técnica nº 06/2025-DEAPS/SAPS/MS"

rodape=["Fonte: SISAPS- Sistema de Informação para Atenção Primária",
        "Desenvolvido por: i9 Consultoria",
        "Página &P de &N"]

# %%
from src.df_b1 import gerar_df_b1

nome_arquivo = "/resultado_b1.xlsx"

df_b1 = gerar_df_b1()

exportar_excel(
    df_b1,
    caminho=destino + nome_arquivo,
    titulo=["B1 - Primeira Consulta Programada por Equipe de Saúde Bucal",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B1"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b1.xlsx

# %%
from src.df_b2 import gerar_df_b2
nome_arquivo = "/resultado_b2.xlsx"
df_b2 = gerar_df_b2()

exportar_excel(
    df_b2,
    caminho=destino + nome_arquivo,
    titulo=["B2 -Tratamento Concluído por Equipe de Saúde Bucal",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B2"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b2.xlsx

# %%
from src.df_b3 import gerar_df_b3

nome_arquivo = "/resultado_b3.xlsx"

df_b3 = gerar_df_b3()

exportar_excel(
    df_b3,
    caminho=destino + nome_arquivo,
    titulo=["B3 - Taxa de exodontias realizadas por Equipe de Saúde Bucal",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B3"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b3.xlsx

# %%
from src.df_b4 import gerar_df_b4

nome_arquivo = "/resultado_b4.xlsx"

df_b4 = gerar_df_b4()

exportar_excel(
    df_b4,
    caminho=destino + nome_arquivo,
    titulo=["B4 -Escovação Supervisionada por equipes de Saúde Bucal (eSB) em faixa etária escolar (de 6 a 12 anos)",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B4"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b4.xlsx

# %%
from src.df_b5 import gerar_df_b5

nome_arquivo = "/resultado_b5.xlsx"

df_b5 = gerar_df_b5()

exportar_excel(
    df_b5,
    caminho=destino + nome_arquivo,
    titulo=["B5 - Procedimentos odontológicos individuais preventivos por equipe de Saúde Bucal - eSB",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B5"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b5.xlsx

# %%
from src.df_b6 import gerar_df_b6

nome_arquivo = "/resultado_b6.xlsx"

df_b6 = gerar_df_b6()

df_b6.head(10)

exportar_excel(
    df_b6,
    caminho=destino + nome_arquivo,
    titulo=["B6 - Tratamento Restaurador Atraumático (ART) por equipe de Saúde Bucal - eSB",
           nota],
    rodape=rodape,    
    coluna_classificacao="CONCEITO",
    coluna_nota_final="NOTA B6"
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_b6.xlsx

# %%
nome_arquivo = "/resultado_parcial_eSB.xlsx"
dfs = [df_b1, df_b2, df_b3, df_b4, df_b5, df_b6]
notas = ["NOTA B1", "NOTA B2", "NOTA B3", "NOTA B4", "NOTA B5", "NOTA B6"]
desempate = ["NOTA B1", "NOTA B2", "NOTA B3", "NOTA B4"]
df_final = consolidar_indicadores(dfs=dfs, notas=notas)
df_final['NOTA FINAL'] = df_final[notas].sum(axis=1)
df_classificado = classificar_e_ordenar_desempate(df_final,desempate=desempate)
caminho = destino + nome_arquivo
exportar_excel(
    df=df_classificado,
    caminho=caminho,
    titulo=["RESULTADO FINAL COMPONENTE QUALIDADE SAÚDE BUCAL 3º Quadrimestre–2025",
            nota],
    rodape=rodape,
    coluna_classificacao="CLASSIFICACAO",
    coluna_nota_final="NOTA FINAL"    
)
# Out:
# Relatório exportado com sucesso: C:/Projetos/ETL/Dados/Caxias/Odonto/Resultado/resultado_parcial_eSB.xlsx
